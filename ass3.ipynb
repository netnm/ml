# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Heart_dataset.csv")
df
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0             1   63    1       typical     145   233    1        2    150
# 1             2   67    1  asymptomatic     160   286    0        2    108
# 2             3   67    1  asymptomatic     120   229    0        2    129
# 3             4   37    1    nonanginal     130   250    0        0    187
# 4             5   41    0    nontypical     130   204    0        2    172
# ..          ...  ...  ...           ...     ...   ...  ...      ...    ...
# 298         299   45    1       typical     110   264    0        0    132
# 299         300   68    1  asymptomatic     144   193    1        0    141
# 300         301   57    1  asymptomatic     130   131    0        0    115
# 301         302   57    0    nontypical     130   236    0        2    174
# 302         303   38    1    nonanginal     138   175    0        0    173
#
#      ExAng  Oldpeak  Slope   Ca        Thal  AHD
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Age', 'Sex', 'ChestPain', 'RestBP', 'Chol', 'Fbs',
#        'RestECG', 'MaxHR', 'ExAng', 'Oldpeak', 'Slope', 'Ca', 'Thal', 'AHD'],
#       dtype='object')

# %%
df=df.drop("Unnamed: 0" , axis=1)

# %%
df
# Out:
#      Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  \
# 0     63    1       typical     145   233    1        2    150      0
# 1     67    1  asymptomatic     160   286    0        2    108      1
# 2     67    1  asymptomatic     120   229    0        2    129      1
# 3     37    1    nonanginal     130   250    0        0    187      0
# 4     41    0    nontypical     130   204    0        2    172      0
# ..   ...  ...           ...     ...   ...  ...      ...    ...    ...
# 298   45    1       typical     110   264    0        0    132      0
# 299   68    1  asymptomatic     144   193    1        0    141      0
# 300   57    1  asymptomatic     130   131    0        0    115      1
# 301   57    0    nontypical     130   236    0        2    174      0
# 302   38    1    nonanginal     138   175    0        0    173      0
#
#      Oldpeak  Slope   Ca        Thal  AHD
# 0        2.3      3  0.0       fixed   No
# ...

# %%
plt.figure(figsize=(16,9))

# %%
df.shape
# Out:
# (303, 14)

# %%
plt.figure(figsize=(16,9))

sns.heatmap(df.corr(numeric_only=True),annot=True ,cmap='coolwarm')

plt.title("THIS IS MY HEATMAP")

plt.show()

# %%
plt.figure(figsize=(16,9))

sns.barplot(df)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(16,9))

sns.countplot(x=df["AHD"] )

plt.title("1:male,0:female")
# Out:
# Text(0.5, 1.0, '1:male,0:female')

# %%
df["AHD"].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df['AHD'] = df['AHD'].map({'Yes': 1, 'No': 0})

# %%
df
# Out:
#      Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  \
# 0     63    1       typical     145   233    1        2    150      0
# 1     67    1  asymptomatic     160   286    0        2    108      1
# 2     67    1  asymptomatic     120   229    0        2    129      1
# 3     37    1    nonanginal     130   250    0        0    187      0
# 4     41    0    nontypical     130   204    0        2    172      0
# ..   ...  ...           ...     ...   ...  ...      ...    ...    ...
# 298   45    1       typical     110   264    0        0    132      0
# 299   68    1  asymptomatic     144   193    1        0    141      0
# 300   57    1  asymptomatic     130   131    0        0    115      1
# 301   57    0    nontypical     130   236    0        2    174      0
# 302   38    1    nonanginal     138   175    0        0    173      0
#
#      Oldpeak  Slope   Ca        Thal  AHD
# 0        2.3      3  0.0       fixed    0
# ...

# %%
plt.figure(figsize=(21,16))
sns.pairplot(df , hue="AHD")

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x=df['AHD'],y=df['Chol'])
plt.show()

# %%
for column in ['Age' , 'MaxHR' ]:
    sns.kdeplot(data=df[column],fill=True)

# %%
plt.figure(figsize=(10,4))
for column in ['Age','MaxHR']:
    sns.kdeplot(data=df[column],fill=True)

# %%
sns.histplot(x=df["Age"])
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.histplot(x=df["Age"],y=df["Chol"])
# Out:
# <Axes: xlabel='Age', ylabel='Chol'>

# %%
counts = df['Sex'].value_counts()

# Draw pie chart
plt.pie(counts, labels=counts.index, autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1a560558190>,
# ...
#  [Text(-0.589024272762713, 0.9290050624707905, '1'),
#   Text(0.589024353978916, -0.9290050109766474, '0')],
#  [Text(-0.32128596696147976, 0.5067300340749765, '68.0%'),
#   Text(0.32128601126122686, -0.5067300059872623, '32.0%')])
